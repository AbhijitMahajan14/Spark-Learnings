# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhijitMahajan14/CS-CodingChallenge/blob/main/pyspark_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install Java
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# Download and install Spark
# !wget -q https://archive.apache.org/dist/spark/spark-3.5.1/spark-3.5.1-bin-hadoop3.tgz
# !tar -xzf spark-3.5.1-bin-hadoop3.tgz

# Set environment variables
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.5.1-bin-hadoop3"

# Install Findspark and PySpark
# !pip install -q findspark
# !pip install pyspark

# Initialize Findspark
import findspark
findspark.init()

# Create Spark session
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Colab Spark").getOrCreate()
print(spark)

# Test Spark with a simple DataFrame
data = [("Alice", 1), ("Bob", 2), ("Carol", 3)]
columns = ["Name", "Value"]
df = spark.createDataFrame(data, columns)
df.show()
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488491 sha256=1703204fcc7a17929a868d89216c6c980d6aa07f3cacb212994016eb9c059978
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# ...
# +-----+-----+
# | Name|Value|
# +-----+-----+
# |Alice|    1|
# |  Bob|    2|
# |Carol|    3|
# +-----+-----+
